# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv("datasets_1111_2005_kidney_disease.csv")

# %%
data.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
data
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
data.corr()
# Out:
#             id       age        bp        sg        al        su       bgr  \
# id    1.000000 -0.185308 -0.245744  0.642156 -0.541993 -0.283416 -0.338673
# age  -0.185308  1.000000  0.159480 -0.191096  0.122091  0.220866  0.244992
# bp   -0.245744  0.159480  1.000000 -0.218836  0.160689  0.222576  0.160193
# sg    0.642156 -0.191096 -0.218836  1.000000 -0.469760 -0.296234 -0.374710
# al   -0.541993  0.122091  0.160689 -0.469760  1.000000  0.269305  0.379464
# su   -0.283416  0.220866  0.222576 -0.296234  0.269305  1.000000  0.717827
# bgr  -0.338673  0.244992  0.160193 -0.374710  0.379464  0.717827  1.000000
# bu   -0.307175  0.196985  0.188517 -0.314295  0.453528  0.168583  0.143322
# sc   -0.268683  0.132531  0.146222 -0.361473  0.399198  0.223244  0.114875
# sod   0.364251 -0.100046 -0.116422  0.412190 -0.459896 -0.131776 -0.267848
# pot  -0.092347  0.058377  0.075151 -0.072787  0.129038  0.219450  0.066966
# ...

# %%
sns.heatmap(dataset.corr())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-aa6664222663> in <module>
# ----> 1 sns.heatmap(dataset.corr())
#
# NameError: name 'dataset' is not defined

# %%
data.describe()

# %%
data.isnull().any()

# %%
data.dtypes

# %%
data.classification.unique()

# %%
data.classification=data.classification.replace("ckd\t","ckd")

# %%
data.classification.unique()

# %%
data.drop("id",axis=1,inplace=True)

# %%
data.head()

# %%
data.classification=[1 if each=="ckd" else 0 for each in data.classification]

# %%
data.head(10)

# %%
data.isnull().sum() #I used the following code to find out how many "NaN" values in which parameter.

# %%
#Sometimes instead of Nan in the data set, "?" value can be found. To solve this problem ; df = data [(data! = '?'). all (axis = 1)] can be used.
df=data.dropna(axis=0)
print(data.shape)
print(df.shape) 
df.head()

# %%
#indexes are not sequential as you can see in the table above. I used the following code to sort indexes.
df.index=range(0,len(df),1)
df.head()

# %%
# I corrected some of the parameters.
df.wc=df.wc.replace("\t6200",6200)
df.wc=df.wc.replace("\t8400",8400) 
print(df.loc[11,["wc"]])
print(df.loc[20,["wc"]])

# %%
#I'll change the data types of some parameters
df.pcv=df.pcv.astype(int)
df.wc=df.wc.astype(int)
df.rc=df.rc.astype(float)
df.info()

# %%
dtype_object=df.select_dtypes(include=['object'])
dtype_object.head()

# %%
for x in dtype_object.columns:
    print("{} unique values:".format(x),df[x].unique())
    print("*"*20)

# %%
#The ordinal values to integers, we can use the pandas DataFrame method replace() to"rbc","pc","pcc","ba","htn","dm","cad","appet","pe" and "ane" to appropriate numeric values
dictonary = {
        "rbc": {
        "abnormal":1,
        "normal": 0,
    },
        "pc":{
        "abnormal":1,
        "normal": 0,
    },
        "pcc":{
        "present":1,
        "notpresent":0,
    },
        "ba":{
        "notpresent":0,
        "present": 1,
    },
        "htn":{
        "yes":1,
        "no": 0,
    },
        "dm":{
        "yes":1,
        "no":0,
    },
        "cad":{
        "yes":1,
        "no": 0,
    },
        "appet":{
        "good":1,
        "poor": 0,
    },
        "pe":{
        "yes":1,
        "no":0,
    },
        "ane":{
        "yes":1,
        "no":0,
    }
}

# %%
#We used categorical values as numerical to replace them.
df=df.replace(dictonary)

# %%
df.head() #All values are numerical.

# %%
df.isnull().any()

# %%
x=df.iloc[:,0:24].values
x

# %%
df.columns

# %%
y=df.iloc[:,24:].values
y

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train

# %%
y_train

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
dt=DecisionTreeClassifier(criterion='entropy',random_state=0)

# %%
dt.fit(x_train,y_train)

# %%
y_pred=dt.predict(x_test)
y_pred

# %%
y_test

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
